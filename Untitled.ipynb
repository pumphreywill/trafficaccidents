# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
file = "US_Accidents_Dec20.csv"
acc_df = pd.read_csv(file)
acc_df.head()
# Out:
#     ID    Source  TMC  Severity   Start_Time      End_Time  Start_Lat  \
# 0  A-1  MapQuest  201         3  2/8/16 5:46  2/8/16 11:00  39.865147
# 1  A-2  MapQuest  201         2  2/8/16 6:07   2/8/16 6:37  39.928059
# 2  A-3  MapQuest  201         2  2/8/16 6:49   2/8/16 7:19  39.063148
# 3  A-4  MapQuest  201         3  2/8/16 7:23   2/8/16 7:53  39.747753
# 4  A-5  MapQuest  201         2  2/8/16 7:39   2/8/16 8:09  39.627781
#
#    Start_Lng  End_Lat  End_Lng  ...  Roundabout Station   Stop  \
# 0 -84.058723      NaN      NaN  ...       False   False  False
# 1 -82.831184      NaN      NaN  ...       False   False  False
# 2 -84.032608      NaN      NaN  ...       False   False  False
# 3 -84.205582      NaN      NaN  ...       False   False  False
# 4 -84.188354      NaN      NaN  ...       False   False  False
#
#   Traffic_Calming Traffic_Signal Turning_Loop Sunrise_Sunset Civil_Twilight  \
# 0           False          False        False          Night          Night
# ...

# %%
del acc_df['End_Lat']

# %%
acc_df['Turning_Loop'].value_counts()
# Out:
# False    1048575
# Name: Turning_Loop, dtype: int64

# %%
acc_df.dtypes
# Out:
# ID                        object
# Source                    object
# TMC                        int64
# Severity                   int64
# Start_Time                object
# End_Time                  object
# Start_Lat                float64
# Start_Lng                float64
# End_Lng                  float64
# Distance(mi)             float64
# Description               object
# Number                   float64
# Street                    object
# Side                      object
# City                      object
# County                    object
# State                     object
# Zipcode                   object
# Country                   object
# Timezone                  object
# Airport_Code              object
# Weather_Timestamp         object
# Temperature(F)           float64
# Wind_Chill(F)            float64
# Humidity(%)              float64
# Pressure(in)             float64
# Visibility(mi)           float64
# Wind_Direction            object
# ...

# %%
acc_df.describe()
# Out:
#                 TMC      Severity     Start_Lat     Start_Lng  End_Lng  \
# count  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06      0.0
# mean   2.094896e+02  2.343474e+00  3.600617e+01 -9.492384e+01      NaN
# std    2.242216e+01  4.865572e-01  4.906603e+00  1.720073e+01      NaN
# min    2.000000e+02  1.000000e+00  2.456309e+01 -1.244583e+02      NaN
# 25%    2.010000e+02  2.000000e+00  3.290783e+01 -1.172749e+02      NaN
# 50%    2.010000e+02  2.000000e+00  3.520253e+01 -8.816329e+01      NaN
# 75%    2.010000e+02  3.000000e+00  4.005737e+01 -8.098193e+01      NaN
# max    4.060000e+02  4.000000e+00  4.899990e+01 -6.806016e+01      NaN
#
#        Distance(mi)         Number  Temperature(F)  Wind_Chill(F)  \
# count  1.048575e+06  393341.000000    1.031419e+06  585456.000000
# mean   1.708838e-01    5108.729174    6.251597e+01      55.756308
# std    1.469699e+00   10009.348695    1.776372e+01      21.625142
# ...

# %%
del acc_df["End_Lng"]

# %%
del acc_df["Humidity(%)"]

# %%
del acc_df["Wind_Chill(F)"]
del acc_df["Pressure(in)"]

# %%
del acc_df["Visibility(mi)"]
del acc_df["Wind_Speed(mph)"]
del acc_df["Start_Lat"]
del acc_df["Start_Lng"]

# %%
acc_df.head()
# Out:
#     ID    Source  TMC  Severity   Start_Time      End_Time  Distance(mi)  \
# 0  A-1  MapQuest  201         3  2/8/16 5:46  2/8/16 11:00          0.01
# 1  A-2  MapQuest  201         2  2/8/16 6:07   2/8/16 6:37          0.01
# 2  A-3  MapQuest  201         2  2/8/16 6:49   2/8/16 7:19          0.01
# 3  A-4  MapQuest  201         3  2/8/16 7:23   2/8/16 7:53          0.01
# 4  A-5  MapQuest  201         2  2/8/16 7:39   2/8/16 8:09          0.01
#
#                                          Description  Number  \
# 0  Right lane blocked due to accident on I-70 Eas...     NaN
# 1  Accident on Brice Rd at Tussing Rd. Expect del...  2584.0
# 2  Accident on OH-32 State Route 32 Westbound at ...     NaN
# 3  Accident on I-75 Southbound at Exits 52 52B US...     NaN
# 4  Accident on McEwen Rd at OH-725 Miamisburg Cen...     NaN
#
#                       Street  ... Roundabout Station   Stop Traffic_Calming  \
# 0                     I-70 E  ...      False   False  False           False
# ...

# %%
del acc_df["Number"]
del acc_df["Astronomical_Twilight"]
del acc_df["Nautical_Twilight"]

# %%
acc_df.head()
# Out:
#     ID    Source  TMC  Severity   Start_Time      End_Time  Distance(mi)  \
# 0  A-1  MapQuest  201         3  2/8/16 5:46  2/8/16 11:00          0.01
# 1  A-2  MapQuest  201         2  2/8/16 6:07   2/8/16 6:37          0.01
# 2  A-3  MapQuest  201         2  2/8/16 6:49   2/8/16 7:19          0.01
# 3  A-4  MapQuest  201         3  2/8/16 7:23   2/8/16 7:53          0.01
# 4  A-5  MapQuest  201         2  2/8/16 7:39   2/8/16 8:09          0.01
#
#                                          Description  \
# 0  Right lane blocked due to accident on I-70 Eas...
# 1  Accident on Brice Rd at Tussing Rd. Expect del...
# 2  Accident on OH-32 State Route 32 Westbound at ...
# 3  Accident on I-75 Southbound at Exits 52 52B US...
# 4  Accident on McEwen Rd at OH-725 Miamisburg Cen...
#
#                       Street Side  ... No_Exit Railway Roundabout Station  \
# 0                     I-70 E    R  ...   False   False      False   False
# ...

# %%
del acc_df["Station"]
del acc_df["Source"]

# %%
acc_df.head()
# Out:
#     ID  TMC  Severity   Start_Time      End_Time  Distance(mi)  \
# 0  A-1  201         3  2/8/16 5:46  2/8/16 11:00          0.01
# 1  A-2  201         2  2/8/16 6:07   2/8/16 6:37          0.01
# 2  A-3  201         2  2/8/16 6:49   2/8/16 7:19          0.01
# 3  A-4  201         3  2/8/16 7:23   2/8/16 7:53          0.01
# 4  A-5  201         2  2/8/16 7:39   2/8/16 8:09          0.01
#
#                                          Description  \
# 0  Right lane blocked due to accident on I-70 Eas...
# 1  Accident on Brice Rd at Tussing Rd. Expect del...
# 2  Accident on OH-32 State Route 32 Westbound at ...
# 3  Accident on I-75 Southbound at Exits 52 52B US...
# 4  Accident on McEwen Rd at OH-725 Miamisburg Cen...
#
#                       Street Side          City  ... Junction No_Exit Railway  \
# 0                     I-70 E    R        Dayton  ...    False   False   False
# 1                   Brice Rd    L  Reynoldsburg  ...    False   False   False
# ...

# %%
x_axis = np.arange(len(acc_df))
tick_locations = [value for value in x_axis]

# %%
plt.figure(figsize=(20,3))
plt.bar(x_axis, acc_df["State"], color='r', alpha=0.5, align="center")
plt.xticks(tick_locations, acc_df["Side"], rotation="vertical")
